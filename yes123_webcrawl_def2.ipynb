# %%
import requests
import re
import json
from bs4 import BeautifulSoup
import lxml
import pymysql
import time

conn= pymysql.connect(host='localhost',
                      port=3306,
                      user='root',
                      password='222210780',
                      db='pythonetl',
                      #charset='utf8_general_ci'
                      charset='utf8',
                      autocommit = True
                      )
cur = conn.cursor()

# %%
hasNext = True #先預設true
pageChange=[0]
job_ids_set=set()
job_links = []


#算一下各方法跑了幾次
sendPost_runtimes = [0]
getJobLinks_runtimes = [0]
writeToDB_runtimes = [0]
getJobIds_runtimes = [0]

# %%
while hasNext == True:  
    resp = sendPost(pageChange[0])
    hasNext = getJobIds(resp) #回傳判斷是否頁面裡面仍然有資料（確保不是最後一頁了）
    pageChange[0]= pageChange[0]+20 #post裡面要帶入的數值 用來換新頁面

getJobLinks(job_ids_set)
insert_count = writeToDB(job_links)  

cur.close()
conn.close()
# Out:
# pageChange=0
# 送出post第[1]輪
# 取得每頁links第[1]輪
# pageChange=20
# 送出post第[2]輪
# 取得每頁links第[2]輪
# pageChange=40
# 送出post第[3]輪
# 取得每頁links第[3]輪
# pageChange=60
# 送出post第[4]輪
# 取得每頁links第[4]輪
# pageChange=80
# 送出post第[5]輪
# 取得每頁links第[5]輪
# pageChange=100
# 送出post第[6]輪
# 取得每頁links第[6]輪
# pageChange=120
# 送出post第[7]輪
# 取得每頁links第[7]輪
# pageChange=140
# 送出post第[8]輪
# 取得每頁links第[8]輪
# pageChange=160
# 送出post第[9]輪
# 取得每頁links第[9]輪
# pageChange=180
# 送出post第[10]輪
# 取得每頁links第[10]輪
# pageChange=200
# 送出post第[11]輪
# 取得每頁links第[11]輪
# pageChange=220
# 送出post第[12]輪
# 取得每頁links第[12]輪
# pageChange=240
# 送出post第[13]輪
# 組合完整link[1]輪
# BD寫入第[1]輪
# BD寫入第[2]輪
# BD寫入第[3]輪
# BD寫入第[4]輪
# BD寫入第[5]輪
# BD寫入第[6]輪
# BD寫入第[7]輪
# BD寫入第[8]輪
# BD寫入第[9]輪
# BD寫入第[10]輪
# BD寫入第[11]輪
# BD寫入第[12]輪
# BD寫入第[13]輪
# BD寫入第[14]輪
# BD寫入第[15]輪
# BD寫入第[16]輪
# BD寫入第[17]輪
# BD寫入第[18]輪
# BD寫入第[19]輪
# BD寫入第[20]輪
# BD寫入第[21]輪
# BD寫入第[22]輪
# BD寫入第[23]輪
# BD寫入第[24]輪
# BD寫入第[25]輪
# BD寫入第[26]輪
# BD寫入第[27]輪
# BD寫入第[28]輪
# BD寫入第[29]輪
# ...

# %%
insert_count = writeToDB(job_links3)
# Out:
# BD寫入第[157]輪
# BD寫入第[158]輪
# BD寫入第[159]輪
# BD寫入第[160]輪
# BD寫入第[161]輪
# BD寫入第[162]輪
# BD寫入第[163]輪
# BD寫入第[164]輪
# BD寫入第[165]輪
# BD寫入第[166]輪
# BD寫入第[167]輪
# BD寫入第[168]輪
# BD寫入第[169]輪
# BD寫入第[170]輪
# BD寫入第[171]輪
# BD寫入第[172]輪
# BD寫入第[173]輪
# BD寫入第[174]輪
# BD寫入第[175]輪
# BD寫入第[176]輪
# BD寫入第[177]輪
# BD寫入第[178]輪
# BD寫入第[179]輪
# BD寫入第[180]輪
# BD寫入第[181]輪
# BD寫入第[182]輪
# BD寫入第[183]輪
# BD寫入第[184]輪
# BD寫入第[185]輪
# BD寫入第[186]輪
# BD寫入第[187]輪
# BD寫入第[188]輪
# BD寫入第[189]輪
# BD寫入第[190]輪
# BD寫入第[191]輪
# BD寫入第[192]輪
# BD寫入第[193]輪
# BD寫入第[194]輪
# BD寫入第[195]輪
# BD寫入第[196]輪
# BD寫入第[197]輪
# BD寫入第[198]輪
# BD寫入第[199]輪
# BD寫入第[200]輪
# BD寫入第[201]輪
# BD寫入第[202]輪
# BD寫入第[203]輪
# BD寫入第[204]輪
# BD寫入第[205]輪
# BD寫入第[206]輪
# BD寫入第[207]輪
# BD寫入第[208]輪
# BD寫入第[209]輪
# BD寫入第[210]輪
# BD寫入第[211]輪
# BD寫入第[212]輪
# BD寫入第[213]輪
# BD寫入第[214]輪
# BD寫入第[215]輪
# BD寫入第[216]輪
# BD寫入第[217]輪
# BD寫入第[218]輪
# BD寫入第[219]輪
# BD寫入第[220]輪
# BD寫入第[221]輪
# BD寫入第[222]輪
# BD寫入第[223]輪

# %%
def sendPost(pageChange):
    print("pageChange=" + str(pageChange))
    url = "https://www.yes123.com.tw/admin/job_refer_list.asp"
    data ={
        "find_key1": "關鍵字","search_feature": "", "search_work": "網路程式設計師","search_multi_loc": "請選擇地區",
        "find_key2": "","search_multi_loc2": "請選擇地區","search_work2": "請選擇職務", "search_job2": "請選擇行業",
        "find_key3": "","search_multi_loc3": "請選擇地區", "search_work3": "請選擇職務",
        "_rdo_1": "1", "search_subj": "",
        "search_work4": "請選擇職務","search_multi_loc4": "請選擇地區",
        "search_multi_loc5": "請選擇地區",
        "_rdo_2": "1","search_work6": "",
        "search_work7": "請選擇職務","search_multi_loc6": "請選擇地區","search_multi_loc7": "請選擇地區",
        "find_sf_subj_mode1": "","s_find_sf_subj_mode1": "","find_se_work_mode1": "","s_find_se_work_mode1": "",
        "find_zone_mode1": "","find_zone_mode2": "","find_zone_mode3": "","find_zone_mode4": "",
        "find_zone_mode5": "", "find_zone_mode6": "","find_zone_mode7": "",
        "find_zone_mode8": "","find_zone_mode9": "","find_zone_mode10": "","s_find_zone_mode1": "", "s_find_zone_mode2": "","s_find_zone_mode4": "",
        "s_find_zone_mode5": "","s_find_zone_mode6": "",
        "s_find_zone_mode7": "","s_find_zone_mode8": "","s_find_zone_mode10": "",
        "find_metro_mode1": "","find_metro_mode2": "","find_metro_mode3": "", "find_metro_mode4": "",
        "find_metro_mode5": "", "find_metro_mode6": "","find_metro_mode7": "","find_metro_mode8": "","find_metro_mode9": "",
        "find_metro_mode10": "","s_find_metro_mode1": "","s_find_metro_mode2": "","s_find_metro_mode3": "",
        "s_find_metro_mode4": "","s_find_metro_mode5": "","s_find_metro_mode6": "","s_find_metro_mode7": "","s_find_metro_mode8": "",
        "s_find_metro_mode9": "","s_find_metro_mode10": "",
        "find_map_mode1": "",
        "find_map_mode2": "",
        "find_map_mode3": "",
        "find_map_mode4": "",
        "find_indy_mode1": "",
        "find_indy_mode2": "",
        "find_indy_mode3": "",
        "find_indy_mode4": "",
        "find_indy_mode5": "",
        "find_indy_mode6": "",
        "find_indy_mode7": "",
        "find_indy_mode8": "",
        "find_indy_mode9": "",
        "find_indy_mode10": "",
        "s_find_indy_mode1": "",
        "s_find_indy_mode2": "",
        "s_find_indy_mode3": "",
        "s_find_indy_mode4": "",
        "s_find_indy_mode5": "",
        "s_find_indy_mode6": "",
        "s_find_indy_mode7": "",
        "s_find_indy_mode8": "",
        "s_find_indy_mode9": "",
        "s_find_indy_mode10": "",
        "find_scl_mode1": "",
        "find_scl_mode2": "",
        "find_scl_mode3": "",
        "find_scl_mode4": "",
        "find_scl_mode5": "",
        "find_scl_mode6": "",
        "find_scl_mode7": "",
        "find_scl_mode8": "",
        "find_scl_mode9": "",
        "find_scl_mode10": "",
        "s_find_scl_mode1": "",
        "s_find_scl_mode2": "",
        "s_find_scl_mode3": "",
        "s_find_scl_mode4": "",
        "s_find_scl_mode5": "",
        "s_find_scl_mode6": "",
        "s_find_scl_mode7": "",
        "s_find_scl_mode8": "",
        "s_find_scl_mode9": "",
        "s_find_scl_mode10": "",
        "find_work_mode1": "2_1011_0001_0003",
        "find_work_mode2": "",
        "find_work_mode3": "",
        "find_work_mode4": "",
        "find_work_mode5": "",
        "find_work_mode6": "",
        "find_work_mode7": "",
        "find_work_mode8": "",
        "find_work_mode9": "",
        "find_work_mode10": "",
        "s_find_work_mode1": "網路程式設計師",
        "s_find_work_mode2": "",
        "s_find_work_mode3": "",
        "s_find_work_mode4": "",
        "s_find_work_mode5": "",
        "s_find_work_mode6": "",
        "s_find_work_mode7": "",
        "s_find_work_mode8": "",
        "s_find_work_mode9": "",
        "s_find_work_mode10": "",
        "find_job_mode1": "",
        "find_job_mode2": "",
        "find_job_mode3": "",
        "find_job_mode4": "",
        "find_job_mode5": "",
        "find_job_mode6": "",
        "find_job_mode7": "",
        "find_job_mode8": "",
        "find_job_mode9": "",
        "find_job_mode10": "",
        "s_find_job_mode1": "",
        "s_find_job_mode2": "",
        "s_find_job_mode3": "", "s_find_job_mode4": "","s_find_job_mode5": "", "s_find_job_mode6": "","s_find_job_mode7": "","s_find_job_mode8": "",
        "s_find_job_mode9": "",
        "s_find_job_mode10": "",
        "find_sche_mode1": "",
        "find_sche_mode2": "",
        "find_sche_mode3": "",
        "find_sche_mode4": "",
        "find_sche_mode5": "",
        "s_find_sche_mode1": "",
        "s_find_sche_mode2": "",
        "s_find_sche_mode3": "",
        "s_find_sche_mode4": "",
        "s_find_sche_mode5": "",
        "_mu_sf_1": "",
        "_mu_se_1": "",
        "_mu_chkbox_2": "",
        "_mu_chkbox_3": "",
        "_mu_wk_1": "",
        "_mu_wk_2": "",
        "_mu_wk_3": "",
        "_mu_wk_4": "",
        "_mu_wk_5": "",
        "_mu_job_1": "",
        "_mu_edu_1": "",
        "_mu_edu_2": "",
        "_mu_edu_3": "",
        "_mu_edu_4": "",
        "_mu_edu_5": "",
        "_mu_edu_6": "",
        "_mu_edu_7": "",
        "_mu_year_1": "",
        "_mu_year_2": "",
        "_mu_lang_1": "",
        "_mu_lang_2": "",
        "_mu_lang_3": "",
        "_mu_psn_1": "",
        "_mu_vc_1": "",
        "_mu_vc_2": "",
        "_mu_vc_3": "",
        "_mu_vc_4": "",
        "_mu_sc_1": "",
        "_mu_sc_2": "",
        "find_subj_mode1": "",
        "find_subj_mode2": "",
        "find_subj_mode3": "",
        "s_find_subj_mode1": "",
        "s_find_subj_mode2": "",
        "s_find_subj_mode3": "",
        "find_sw_mode1": "",
        "find_sw_mode2": "",
        "find_sw_mode3": "",
        "find_sw_mode4": "",
        "find_sw_mode5": "",
        "s_find_sw_mode1": "",
        "s_find_sw_mode2": "",
        "s_find_sw_mode3": "",
        "s_find_sw_mode4": "",
        "s_find_sw_mode5": "",
        "find_cert_mode1": "",
        "find_cert_mode2": "",
        "find_cert_mode3": "",
        "find_cert_mode4": "",
        "find_cert_mode5": "",
        "s_find_cert_mode1": "",
        "s_find_cert_mode2": "",
        "s_find_cert_mode3": "",
        "s_find_cert_mode4": "",
        "s_find_cert_mode5": "",
        "order_by": "m_date",
        "order_ascend": "desc",
        "strrec": "0",
        "search_key_word": "",
        "search_type": "job",
        "us_menu": "",
        "search_item": "1",
        "search_from": "joblist",
        "job_show_type": "L"
    }

    headers = {
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        "Cache-Control": "no-cache",
        "Connection": "keep-alive",
        "Content-Length": "4456",
        "Content-Type": "application/x-www-form-urlencoded",
        "Cookie": "_sh_c_1=search_type%3Ajob%7Csearch_item%3A1%7Cs_find_work_mode1%3A%E7%B6%B2%E8%B7%AF%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88%E5%B8%AB%7Cfind_work_mode1%3A2_1011_0001_0003%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_4=search_type%3Ajob%7Csearch_item%3A1%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_2=search_type%3Ajob%7Csearch_item%3A1%7Cs_find_work_mode1%3A%E7%B6%B2%E8%B7%AF%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88%E5%B8%AB%7Cfind_work_mode1%3A2_1011_0001_0003%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_5=search_type%3Ajob%7Csearch_item%3A1%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_3=search_type%3Ajob%7Csearch_item%3A1%7Cs_find_work_mode1%3A%E7%B6%B2%E8%B7%AF%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88%E5%B8%AB%7Cfind_work_mode1%3A2_1011_0001_0003%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; ASPSESSIONIDQSDABSSA=FDDJBGCCNCDNCMKBIADCFNNL; ClientIP=111.248.68.173; _ga=GA1.3.1435425697.1516530457; __auc=7bfc43e816118425a42483962d3; yes123_make_cookie=462043afe6a3ef6a768540ed7a528319; ASPSESSIONIDQQBCBSTB=KPGAGBNCKCHGOENJBLJKJLPD; __asc=78f7471f1611dbd4f8550c7b5ff; _gid=GA1.3.1488024961.1516622401; view%5Fjob%5Fid%5Fstr=13690%5F11395000%40%21%4020120614144726%5F9324965%40%21%40Java%E5%B7%A5%E7%A8%8B%E5%B8%AB; ASPSESSIONIDSQASRSRQ=MJKINJNCFENDCADJLEEKAGOB; ASPSESSIONIDSSDAATSB=GMBKPKOCFFCMLMBGFIGEEDHJ; citrix_ns_id=6ZYQxtpIazqg5eMw4MDVncf3sOoA000; ASP.NET_SessionId=783262147; StepCookie_id=783262147; step=50",
        "Host": "www.yes123.com.tw",
        "Origin": "https://www.yes123.com.tw",
        "Pragma": "no-cache",
        "Referer": "https://www.yes123.com.tw/admin/job_refer_list.asp",
        "Upgrade-Insecure-Requests": "1",
        "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36"
    }
    data["strrec"]=pageChange
    resp = requests.post(url, data=data, headers=headers)
    resp.encoding = 'utf-8'
    sendPost_runtimes[0] = sendPost_runtimes[0]+ 1
    print("送出post第" + str(sendPost_runtimes) +"輪")
    return resp

# %%
def getJobIds(resp):
    resp.encoding = 'utf-8'
    soup=BeautifulSoup(resp.text,"lxml")
    html = soup.select("div.SLV_Wrapper > div.box_detail > div.box_detail_left")
    if not html:
        return False
    else:
        html_str = str(html[0])
        job_ids_set.update(re.findall('window.open(.*);',html_str))
        getJobIds_runtimes[0] = getJobIds_runtimes[0]+ 1
        print("取得每頁links第" + str(getJobIds_runtimes) +"輪")
        return True

# %%
def getJobLinks(job_ids_set):
    
    url_temp = "https://www.yes123.com.tw/admin/{}"
    for job_id in job_ids_set:
        job_links.append(url_temp.format(job_id).replace("('","").replace("')","").replace("&amp;","&")) 
    getJobLinks_runtimes[0] = getJobLinks_runtimes[0] + 1
    print("組合完整link" + str(getJobLinks_runtimes) +"輪")

# %%
def writeToDB(job_links3):
    for link in job_links3:
        time.sleep(1)
        headers = json.loads(r'''{
            "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
            "Accept-Encoding": "gzip, deflate, br",
            "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
            "Cache-Control": "max-age=0",
            "Connection": "keep-alive",
            "Cookie": "_sh_c_3=search_type%3Ajob%7Csearch_item%3A1%7Cs_find_work_mode1%3A%E7%B6%B2%E8%B7%AF%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88%E5%B8%AB%7Cfind_work_mode1%3A2_1011_0001_0003%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_4=search_type%3Ajob%7Csearch_item%3A1%7Cs_find_work_mode1%3A%E7%B6%B2%E8%B7%AF%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88%E5%B8%AB%7Cfind_work_mode1%3A2_1011_0001_0003%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_5=search_type%3Ajob%7Csearch_item%3A1%7Cs_find_work_mode1%3A%E7%B6%B2%E8%B7%AF%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88%E5%B8%AB%7Cfind_work_mode1%3A2_1011_0001_0003%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_1=search_type%3Ajob%7Csearch_item%3A1%7Cs_find_work_mode1%3A%E6%B3%95%E5%8B%99%EF%BC%8F%E6%99%BA%E8%B2%A1%E4%B8%BB%E7%AE%A1%7Cfind_work_mode1%3A2_1001_0002_0001%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_2=search_type%3Ajob%7Csearch_item%3A1%7Cs_find_work_mode1%3A%E6%B3%95%E5%8B%99%EF%BC%8F%E6%99%BA%E8%B2%A1%E4%B8%BB%E7%AE%A1%7Cfind_work_mode1%3A2_1001_0002_0001%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; ASPSESSIONIDQSDABSSA=FDDJBGCCNCDNCMKBIADCFNNL; _ga=GA1.3.1435425697.1516530457; __auc=7bfc43e816118425a42483962d3; yes123_make_cookie=462043afe6a3ef6a768540ed7a528319; ASPSESSIONIDQQBCBSTB=KPGAGBNCKCHGOENJBLJKJLPD; _gid=GA1.3.1488024961.1516622401; ASPSESSIONIDSQASRSRQ=MJKINJNCFENDCADJLEEKAGOB; ASPSESSIONIDSSDAATSB=GMBKPKOCFFCMLMBGFIGEEDHJ; ASPSESSIONIDQQADBSSA=FAFPHNOCHKEHBEIKMMDBKNMF; ASPSESSIONIDQQDRQSRR=MDPJFKEDPBGPDCNIMPDPKHPH; ASPSESSIONIDQQCAATSA=HIABAOFDDAAECEBGEBIGDPMJ; ASPSESSIONIDQQDTSTSR=LDOLHKHDFDOJPONGNIBHMEMB; ClientIP=61.231.154.120; ASPSESSIONIDACASSSRS=FICJGNGDHAJMKLJHPKGLMDBH; __asc=b6c6d68916122e52325507cad54; ASPSESSIONIDSSACASSA=NOPNLDJDMBKCMDPJOIGNNOGG; citrix_ns_id=tUiZBXbSE/eJwDqvagRThUYsRt0A000; ASP.NET_SessionId=960225259; StepCookie_id=960225259; view%5Fjob%5Fid%5Fstr=%24%21%2413690%5F11395000%40%21%4020120614144726%5F9324965%40%21%40Java%E5%B7%A5%E7%A8%8B%E5%B8%AB%24%21%2416606102002%40%21%4020170216142920%5F7834681%40%21%40%E8%BB%9F%E9%AB%94%E5%B7%A5%E7%A8%8B%E5%B8%AB%28A0201%29%24%21%2420090702135907%5F28859952%40%21%4020171216051852%5F11621799%40%21%40%E5%B0%88%E6%A1%88%E5%B7%A5%E7%A8%8B%E5%B8%AB%28%E5%84%B2%E5%82%99%E5%B9%B9%E9%83%A8%29%24%21%2420130503135910%5F24420191%40%21%4020170804113937%5F150684%40%21%40%E5%89%8D%E7%AB%AF%E8%BB%9F%E9%AB%94%E5%B7%A5%E7%A8%8B%E5%B8%AB%28%E7%A6%8F%E5%88%A9%E4%BD%B3%29%24%21%2416606102002%40%21%4020141106150119%5F6460033%40%21%40%28PHP%29%E5%B7%A5%E7%A8%8B%E5%B8%AB+%28A0402%29%24%21%2416606102002%40%21%4020141106150257%5F499708%40%21%40%E5%B7%A5%E7%A8%8B%E5%B8%AB%28E0804%29; step=151",
            "Host": "www.yes123.com.tw",
            "Upgrade-Insecure-Requests": "1",
            "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36"
        }''')
        resp = requests.get(link,headers = headers)
        soup = BeautifulSoup(resp.text,"lxml")
        
        job_title = soup.select("body > div.all > div.skin_middle > div.jobname")[0].select("a:nth-of-type(1)")[0].text
        try:
            addr_1 = soup.select("body > div.all > div.skin_middle > div.content > div.left")[0].select("div.comp_detail > ul:nth-of-type(1)")[0].select("li:nth-of-type(2) > span.rr")[0]
            addr = addr_1.next_element.strip()
        except:
            addr = "erro"
        try:
            reqirement_raw = soup.select("div.skin_middle > div.content > div.left")[0].select("div:nth-of-type(9) > ul")[0].select(" li:nth-of-type(1)")
            reqirement = reqirement_raw[0].text
        except:
            reqirement = "erro"
        company = soup.select("div.skin_middle > div.jobname > div.jobname_title > p > a")[0].text
        sql_insert_template = """insert into jobs_yes123 (site, company, address,job_title, reqirement,link) values("yes123", '%s', '%s', '%s','%s','%s')"""
        sql_insert_data = sql_insert_template%(company,addr,job_title,reqirement,link)
        cur.execute(sql_insert_data)
        writeToDB_runtimes[0] = writeToDB_runtimes[0]+1 
        print("BD寫入第" + str(writeToDB_runtimes) +"輪")

# %%
job_links
# Out:
# ['https://www.yes123.com.tw/admin/job_refer_comp_job_detail2.asp?p_id=20161213154216_23606705&job_id=20170111141344_21738292',
#  'https://www.yes123.com.tw/admin/job_refer_comp_job_detail2.asp?p_id=7840496_28806392&job_id=20170303102732_31984515',
#  'https://www.yes123.com.tw/admin/job_refer_comp_job_detail2.asp?p_id=20170606153705_24369238&job_id=20170607015201_23280305',
#  'https://www.yes123.com.tw/admin/job_refer_comp_job_detail2.asp?p_id=16606102002&job_id=20150330110651_7138768',
#  'https://www.yes123.com.tw/admin/job_refer_comp_job_detail2.asp?p_id=20120720161532_24442955&job_id=20120723160301_10232958',
#  'https://www.yes123.com.tw/admin/job_refer_comp_job_detail2.asp?p_id=20140206142429_12204275&job_id=20140318141454_6238051',
#  'https://www.yes123.com.tw/admin/job_refer_comp_job_detail2.asp?p_id=9280010_14053007&job_id=20171218133931_7763452',
#  'https://www.yes123.com.tw/admin/job_refer_comp_job_detail2.asp?p_id=6933971_09461025&job_id=20150917114206_7983610',
# ...

# %%
job_links3=job_links[157:224]
